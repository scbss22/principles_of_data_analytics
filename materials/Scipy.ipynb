# %% [markdown]
# # **Scipy**

# %%
# Numercial arrays.
import numpy as np

# Scientific Computing.
import scipy as sp

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ## Resources
#
# https://docs.scipy.org/doc/scipy/tutorial/index.html

# %% [markdown]
# ## Fit a line

# %%
# Range of x values.
x = np.linspace(-10.0, 10.0, 21)

# Range of y values.
y = 4.0 * x + 2.0 + np.random.normal(0.0, 3.0, x.shape)

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# %%
# Fit a line.
m, c = np.polyfit(x, y, 1)

# Show.
m, c
# Out:
# (np.float64(4.006621154373827), np.float64(1.6821772393576233))

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# Plot the line.
plt.plot(x, m * x + c, label='Fit')

# %%
# Fit a line.
coeffs = np.polyfit(x, y, 1)

# Show.
coeffs
# Out:
# array([4.00662115, 1.68217724])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
f
# Out:
# array([-38.3840343 , -34.37741315, -30.370792  , -26.36417084,
#        -22.35754969, -18.35092853, -14.34430738, -10.33768622,
#         -6.33106507,  -2.32444392,   1.68217724,   5.68879839,
#          9.69541955,  13.7020407 ,  17.70866186,  21.71528301,
#         25.72190417,  29.72852532,  33.73514647,  37.74176763,
#         41.74838878])

# %%
# Show y.
y
# Out:
# array([-39.07172894, -34.63563285, -34.39369345, -26.24127822,
#        -23.24753161, -14.99577462, -15.86722961,  -5.62768916,
#         -7.37774056,  -4.54571554,  -0.85352006,  12.72550064,
#          8.74586986,  16.9395448 ,  17.99709722,  21.78897295,
#         25.96948068,  28.7604009 ,  31.90518747,  38.15777635,
#         39.19342577])

# %% [markdown]
# ## Evaluate
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# Sum of squares of residuals.
ss_res = np.sum((y - f)**2)

# Show.
ss_res
# Out:
# np.float64(137.7853573648365)

# %%
# Mean of y.
y_bar = np.mean(y)

# Show.
y_bar
# Out:
# np.float64(1.682177239357625)

# %%
# Total sum of squares.
ss_tot = np.sum((y - y_bar)**2)

# Show.
ss_tot
# Out:
# np.float64(12498.605424865234)

# %%
# Ratio.
ss_res / ss_tot
# Out:
# np.float64(0.011024058499416319)

# %%
# R^2 value.
1.0 - (ss_res / ss_tot)
# Out:
# np.float64(0.9889759415005837)

# %% [markdown]
# ## Using scipy

# %%
# Use scipy to fit a line.
fit = sp.stats.linregress(x, y)

# Show.
fit
# Out:
# LinregressResult(slope=np.float64(4.006621154373825), intercept=np.float64(1.682177239357625), rvalue=np.float64(0.994472695201122), pvalue=np.float64(4.584296618039543e-20), stderr=np.float64(0.09704638677938188), intercept_stderr=np.float64(0.5876450545929554))

# %%
# Slope.
fit.slope
# Out:
# np.float64(4.006621154373825)

# %%
# Intercept.
fit.intercept
# Out:
# np.float64(1.682177239357625)

# %%
# R value.
fit.rvalue
# Out:
# np.float64(0.994472695201122)

# %%
# R2 value.
fit.rvalue**2
# Out:
# np.float64(0.9889759415005838)

# %% [markdown]
# End of Scipy
